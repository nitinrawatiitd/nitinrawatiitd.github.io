# %% [markdown]
# DLRM is an architecture proposed by facebook - https://github.com/facebookresearch/dlrm
#
# Articles explaining the concepts in DLRM -
# * https://medium.com/swlh/deep-learning-recommendation-models-dlrm-a-deep-dive-f38a95f47c2c
# * https://analyticsindiamag.com/facebook-open-sourcing-dlrm-is-a-game-changer-for-recommendation-models/
# * https://www.youtube.com/watch?v=r9J3UZmddC4
#
# Article on modern recommender systems (including DLRM) -
# https://towardsdatascience.com/modern-recommender-systems-a0c727609aa8
