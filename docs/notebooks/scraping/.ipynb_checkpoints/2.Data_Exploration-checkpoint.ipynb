# %%
import pandas as pd
import numpy as np
import glob

from bokeh.palettes import Spectral4
from bokeh.plotting import figure, show
from bokeh.palettes import Category10, Category20, Category20b, Category20c
from bokeh.palettes import Greys256, Inferno256, Magma256, Plasma256

# %% [markdown]
# # Loading the data

# %%
#load the datasets and combine

extension = 'csv'
all_filenames = [i for i in glob.glob('scraped_data/*.{}'.format(extension))]

# %%
relevant_cols = ['@context', '@type', 'offers', 'brand', 'name', 'description',
                 'category', 'url', 'sku', 'image', 'availability', 'price',
                 'priceCurrency', 'priceValidUntil', 'date']

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f)[relevant_cols] for f in all_filenames ])

#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False)

# %%
df1 = pd.read_csv('scraped_data/FastnFresh_2021-01-31.csv')
df2 = pd.read_csv('scraped_data/FastnFresh_2021-02-01.csv')

# %%
print (df1.shape, df2.shape)
# Out:
# (161, 17) (158, 15)

# %%
df1.columns
# Out:
# Index(['@context', '@type', 'name', 'brand', 'sku', 'mpn', 'description',
#        'url', 'image', 'itemCondition', 'offers', 'price', 'priceCurrency',
#        'availability', 'priceValidUntil', 'gtin14', 'date'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['@context', '@type', 'offers', 'brand', 'name', 'description',
#        'category', 'url', 'sku', 'image', 'availability', 'price',
#        'priceCurrency', 'priceValidUntil', 'date'],
#       dtype='object')

# %% [markdown]
# # Analysis

# %%
combined_csv.shape
# Out:
# (5428, 18)

# %%
combined_csv.columns
# Out:
# Index(['@context', '@type', 'offers', 'brand', 'name', 'description',
#        'category', 'url', 'sku', 'image', 'availability', 'price',
#        'priceCurrency', 'priceValidUntil', 'date', 'mpn', 'itemCondition',
#        'gtin14'],
#       dtype='object')

# %%
combined_csv
# Out:
#                @context  @type  \
# 0     http://schema.org  Offer
# 1     http://schema.org  Offer
# 2     http://schema.org  Offer
# 3     http://schema.org  Offer
# 4     http://schema.org  Offer
# ..                  ...    ...
# 156  https://schema.org  Offer
# 157  https://schema.org  Offer
# 158  https://schema.org  Offer
# 159  https://schema.org  Offer
# 160  https://schema.org  Offer
#
#                                                 offers  \
# 0    [{'@type': 'Offer', 'name': 'Default Title', '...
# 1    [{'@type': 'Offer', 'name': 'Default Title', '...
# 2    [{'@type': 'Offer', 'name': 'Default Title', '...
# 3    [{'@type': 'Offer', 'name': 'Default Title', '...
# 4    [{'@type': 'Offer', 'name': 'Default Title', '...
# ..                                                 ...
# 156  [{'@type': 'Offer', 'price': '699.00', 'priceC...
# 157  [{'@type': 'Offer', 'price': '39.00', 'priceCu...
# 158  [{'@type': 'Offer', 'price': '196.00', 'priceC...
# 159  [{'@type': 'Offer', 'price': '29.00', 'priceCu...
# 160  [{'@type': 'Offer', 'price': '24.00', 'priceCu...
#
#                                                  brand  \
# 0                                      {'name': 'FFG'}
# 1                                      {'name': 'FFG'}
# 2                                      {'name': 'FFG'}
# 3                                      {'name': 'FFG'}
# 4                                      {'name': 'FFG'}
# ..                                                 ...
# 156  {'@type': 'Brand', 'name': 'FAST AND FRESH GLO...
# 157                  {'@type': 'Brand', 'name': 'FFG'}
# 158                  {'@type': 'Brand', 'name': 'FFG'}
# 159                  {'@type': 'Brand', 'name': 'FFG'}
# 160                  {'@type': 'Brand', 'name': 'FFG'}
#
#                                            name  \
# 0                                 Default Title
# 1                                 Default Title
# 2                                 Default Title
# 3                                 Default Title
# 4                                 Default Title
# ..                                          ...
# 156                             VITAMIN-C COMBO
# 157    Water Melon (Price per Pcs 2.5kg to 3kg)
# 158  Zespri Green Kiwi (Price per Box of 4 pcs)
# 159           Zuchini Green (Price per 500 gms)
# 160           Zuchini Yellow (Price per 250gms)
#
#                                            description      category  \
# 0    Health benefits of Amla-:\n\n\nIt improves eye...         Fruit
# 1    Health benefits of pomegranate (Anar)-:\n\n\nP...         Fruit
# 2    Interesting Health Benefits Of Golden Apple-:\...         Fruit
# 3    Some amazing Health benefits of (Apple grenny ...  Exotic Fruit
# 4    Surprising and Impressive Health Benefits of A...         Fruit
# ..                                                 ...           ...
# 156  Introducing FFG VITAMIN-C COMBO to boost your ...           NaN
# 157  \nHere are the top health benefits of eating w...           NaN
# 158  \n\nZespri kiwifruit are an excellent source o...           NaN
# 159  Here are  evidence-based benefits of zucchini....           NaN
# 160  Here are  evidence-based benefits of zucchini....           NaN
#
#                                                    url  sku  \
# 0    https://fastandfresh.in/products/amla?variant=...  AM2
# 1    https://fastandfresh.in/products/anar-kandhari...  AN1
# 2    https://fastandfresh.in/products/apple-golden-...  AP4
# 3    https://fastandfresh.in/products/apple-green-i...  AP1
# 4    https://fastandfresh.in/products/apple-shimla-...  AP9
# ..                                                 ...  ...
# 156  https://fastandfresh.in/products/vitamin-c-com...  NaN
# 157  https://fastandfresh.in/products/water-melon?v...  WA1
# 158  https://fastandfresh.in/products/zesperi-green...  KZG
# 159  https://fastandfresh.in/products/zuchini-green...  ZU1
# 160  https://fastandfresh.in/products/zuchini-yello...  ZU2
#
#                                                  image  \
# 0    {'@type': 'ImageObject', 'url': 'https://cdn.s...
# 1    {'@type': 'ImageObject', 'url': 'https://cdn.s...
# 2    {'@type': 'ImageObject', 'url': 'https://cdn.s...
# 3    {'@type': 'ImageObject', 'url': 'https://cdn.s...
# 4    {'@type': 'ImageObject', 'url': 'https://cdn.s...
# ..                                                 ...
# 156  https://cdn.shopify.com/s/files/1/0279/6876/60...
# 157  https://cdn.shopify.com/s/files/1/0279/6876/60...
# 158  https://cdn.shopify.com/s/files/1/0279/6876/60...
# 159  https://cdn.shopify.com/s/files/1/0279/6876/60...
# 160  https://cdn.shopify.com/s/files/1/0279/6876/60...
#
#                    availability   price priceCurrency priceValidUntil  \
# 0    https://schema.org/InStock   18.00           INR      2021-02-11
# 1    https://schema.org/InStock  128.00           INR      2021-02-11
# 2    https://schema.org/InStock  139.00           INR      2021-02-11
# 3    https://schema.org/InStock  112.00           INR      2021-02-11
# 4    https://schema.org/InStock  195.00           INR      2021-02-11
# ..                          ...     ...           ...             ...
# 156  https://schema.org/InStock     699           INR      2021-02-10
# 157  https://schema.org/InStock      39           INR      2021-02-10
# 158  https://schema.org/InStock     196           INR      2021-02-10
# 159  https://schema.org/InStock      29           INR      2021-02-10
# 160  https://schema.org/InStock      24           INR      2021-02-10
#
#            date  mpn                    itemCondition  gtin14
# 0    2021-02-01  NaN                              NaN     NaN
# 1    2021-02-01  NaN                              NaN     NaN
# 2    2021-02-01  NaN                              NaN     NaN
# 3    2021-02-01  NaN                              NaN     NaN
# 4    2021-02-01  NaN                              NaN     NaN
# ..          ...  ...                              ...     ...
# 156  2021-01-11  NaN  https://schema.org/NewCondition     NaN
# 157  2021-01-11  NaN  https://schema.org/NewCondition     NaN
# 158  2021-01-11  NaN  https://schema.org/NewCondition     NaN
# 159  2021-01-11  NaN  https://schema.org/NewCondition     NaN
# 160  2021-01-11  NaN  https://schema.org/NewCondition     NaN
#
# [5428 rows x 18 columns]

# %% [markdown]
# ## Plot trends of some items

# %%
items_list = combined_csv['name'].unique()
items_list = ['Zuchini Green (Price per 500 gms)',
              'Zuchini Yellow (Price per 250gms)',
              'Raspberry/Cape Goosberry (Price per 250gms)',
              'avacados','asparagus-thai']

# %%
p = figure(plot_width=1400, plot_height=600, x_axis_type="datetime")
p.title.text = 'Click on legend entries to mute the corresponding lines'

for name, color in zip(items_list, Inferno256):
    df = combined_csv[combined_csv['name']==name].reset_index(drop=True)
    df.sort_values(by='date',inplace=True)
    df['date'] = pd.to_datetime(df['date'])
    p.line(df['date'], df['price'], line_width=2, color=color, alpha=0.8,
           muted_color=color, muted_alpha=0.2, legend_label=name)

p.legend.location = "top_left"
p.legend.click_policy="mute"

show(p)

# %%
for name, color in zip(items_list, Inferno256):
    print (name,color)
# Out:
# Zuchini Green (Price per 500 gms) #000003
# Zuchini Yellow (Price per 250gms) #000004
# Raspberry/Cape Goosberry (Price per 250gms) #000006
# avacados #010007
# asparagus-thai #010109

# %% [markdown]
# ## Item counts by day

# %%
pd.pivot_table(combined_csv,index='date',values='name',aggfunc=len)
# Out:
#             name
# date
# 2020-12-28   154
# 2020-12-29   154
# 2020-12-30   155
# 2020-12-31   156
# 2021-01-01   157
# 2021-01-02   157
# 2021-01-03   157
# 2021-01-04   157
# 2021-01-05   157
# 2021-01-06   157
# 2021-01-07   159
# 2021-01-08   160
# 2021-01-09   160
# 2021-01-10   160
# 2021-01-11   161
# 2021-01-12   160
# 2021-01-13   159
# 2021-01-14   160
# 2021-01-15   160
# 2021-01-16   162
# 2021-01-18   162
# 2021-01-19   162
# 2021-01-20   162
# 2021-01-21   164
# 2021-01-22   164
# 2021-01-23   163
# 2021-01-25   162
# 2021-01-26   162
# 2021-01-27   162
# 2021-01-28   162
# 2021-01-29   161
# 2021-01-30   161
# 2021-01-31   161
# 2021-02-01   158

# %% [markdown]
# ## New items added recently

# %%
l1 = combined_csv[combined_csv['date']=='2021-01-20']['name'].to_list()
l2 = combined_csv[combined_csv['date']=='2021-02-01']['name'].to_list()

# %%
new_list = np.setdiff1d(l2,l1)
new_list
# Out:
# array(['Default Title'], dtype='<U13')

# %%
l2
# Out:
# ['Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title',
#  'Default Title']
